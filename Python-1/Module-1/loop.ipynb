# %%
# For loop:

for i in range(5):
    print(i, "Hello, World!")
# Out:
# 0 Hello, World!
# 1 Hello, World!
# 2 Hello, World!
# 3 Hello, World!
# 4 Hello, World!

# %%
# While loop:

count = 1
while count < 5:
    print(count, "Hello, World!")
    count += 1
# Out:
# 1 Hello, World!
# 2 Hello, World!
# 3 Hello, World!
# 4 Hello, World!
