# %%
raining = True
if raining == True:
    print("Take an umbrella")
else: 
    print("No need for an umbrella")
# Out:
# Take an umbrella

# %%
taka = 1000
if taka > 500:
    print("Ghurte jabo")
elif taka  > 400:
    print("Basay order korbo")
elif taka > 300:
    print("Food court a jabo")
else: 
    print("Basay thakbo")
# Out:
# Ghurte jabo
