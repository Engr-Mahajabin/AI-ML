# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah","Sakib"],
    "City": ["New York", "Los Angeles", "Newark", "Boston", "New Delhi", "Chicago", "New Orleans", "Houston","H Los Ang"],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "Marketing", "Finance", "HR", "HR"],
    "Salary": [50000, 60000, 55000, 70000, 52000, 58000, 62000, 51000,70000]
}

df = pd.DataFrame(data)
df
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 1      Bob  Los Angeles         IT   60000
# 2  Charlie       Newark    Finance   55000
# 3    David       Boston         IT   70000
# 4      Eve    New Delhi         HR   52000
# 5    Frank      Chicago  Marketing   58000
# 6    Grace  New Orleans    Finance   62000
# 7   Hannah      Houston         HR   51000
# 8    Sakib    H Los Ang         HR   70000

# %%
df.loc[df['City'].str.contains("New")]
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 2  Charlie       Newark    Finance   55000
# 4      Eve    New Delhi         HR   52000
# 6    Grace  New Orleans    Finance   62000

# %%
df.loc[df['City'].str.contains("new",case=False)]
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 2  Charlie       Newark    Finance   55000
# 4      Eve    New Delhi         HR   52000
# 6    Grace  New Orleans    Finance   62000

# %%
# starts with Los

df.loc[df['City'].str.contains(r"^Los")]
# Out:
#   Name         City Department  Salary
# 1  Bob  Los Angeles         IT   60000

# %%
#end with rk

df.loc[df['City'].str.contains(r"rk$")]
# Out:
#       Name      City Department  Salary
# 0    Alice  New York         HR   50000
# 2  Charlie    Newark    Finance   55000

# %%
# name starts with a vowel 

df.loc[df['Name'].str.contains(r"^[AEIOU]")]
# Out:
#     Name       City Department  Salary
# 0  Alice   New York         HR   50000
# 4    Eve  New Delhi         HR   52000

# %%
# string contains New or Los

df.loc[df['City'].str.contains(r"New|Los")]
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 1      Bob  Los Angeles         IT   60000
# 2  Charlie       Newark    Finance   55000
# 4      Eve    New Delhi         HR   52000
# 6    Grace  New Orleans    Finance   62000
# 8    Sakib    H Los Ang         HR   70000

# %%
import numpy as np
import pandas as pd

# আপনার দেওয়া স্টুডেন্ট ডেটা লিস্ট আকারে সাজানো হয়েছে
student_data = {
    "StudentID": [
        "PH1001", "PH1002", "PH1003", "PH1004", "PH1005", 
        "PH1006", "PH1007", "PH1008", "PH1009", "PH1010", 
        "PH1011", "PH1012", "PH1013", "PH1014", "PH1015", 
        "PH1016", "PH1017", "PH1018", "PH1019", "PH1020"
    ],
    "FullName": [
        "Alif Rahman", "Fatima Akhter", "Imran Hossain", "Jannatul Ferdous", "Kamal Uddin", 
        "Laila Begum", "Mahmudul Hasan", "Nadia Islam", "Omar Faruq", "Priya Sharma", 
        "Rahim Sheikh", "Sadia Chowdhury", "Tanvir Ahmed", "Urmi Akter", "Wahiduzzaman", 
        "Ziaur Rahman", "Afsana Mimi", "Babul Ahmed", "Faria Rahman", "Nasir Khan"
    ],
    "Data Structure Marks": [
        85, 92, 88, 78, None, 
        75, 80, 81, 72, 89, 
        None, 85, 75, None, 86, 
        94, 90, 88, None, 86
    ],
    "Algorithm Marks": [
        85, 92, 88, 78, None, 
        75, 80, 81, 72, 89, 
        None, 85, 75, None, 86, 
        94, 90, 88, None, 86
    ],
    "Python Marks": [
        88, None, 85, 82, 95, 
        78, None, 85, 76, 88, 
        91, 87, 79, None, 84, 
        None, 93, 85, None, 89
    ],
    "CompletionStatus": [
        "Completed", "In Progress", "Completed", "Completed", "In Progress", 
        "Completed", "In Progress", "Completed", "Completed", "Completed", 
        "In Progress", "Completed", "Completed", "Not Started", "Completed", 
        "In Progress", "Completed", "Completed", "Not Started", "Completed"
    ],
    "EnrollmentDate": [
        "2024-01-15", "2024-01-20", "2024-02-10", "2024-02-12", "2024-03-05", 
        "2024-03-08", "2024-04-01", "2024-04-22", "2024-05-16", "2024-05-20", 
        "2024-06-11", "2024-06-14", "2024-07-02", "2024-07-09", "2024-08-18", 
        "2024-08-21", "2025-09-01", "2025-09-05", "2025-09-15", "2025-10-02"
    ],
    "Instructor": [
        "Mr. Karim", "Ms. Salma", "Mr. Karim", "Ms. Salma", "Mr. Karim", 
        "Ms. Salma", "Mr. Karim", "Ms. Salma", "Mr. David", "Ms. Salma", 
        "Mr. Karim", "Ms. Salma", "Mr. David", "Ms. Salma", "Mr. Karim", 
        "Ms. Salma", "Mr. Karim", "Ms. Salma", "Mr. David", "Ms. Salma"
    ],
    "Location": [
        "Dhaka", "Chattogram", "Dhaka", "Sylhet", "Chattogram", 
        "Rajshahi", "Dhaka", "Chattogram", "Dhaka", "Sylhet", 
        "Khulna", "Chattogram", "Dhaka", "Rajshahi", "Dhaka", 
        "Chattogram", "Dhaka", "Sylhet", "Chattogram", "Dhaka"
    ]
}

# ডিকশনারি থেকে পান্ডাস ডেটাফ্রেম তৈরি
df = pd.DataFrame(student_data)

# 'student_data.csv' নামে ফাইলটি সেভ করা হচ্ছে
df.to_csv("student_data.csv", index=False)

print("আপনার student_data.csv ফাইলটি সফলভাবে তৈরি হয়েছে!")
# Out:
# আপনার student_data.csv ফাইলটি সফলভাবে তৈরি হয়েছে!

# %%
# Adding New Colums
df = pd.read_csv('student_data.csv')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# adding a column with constant value 

df['Country'] = 'Bangladesh'

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['Total Marks'] = df['Data Structure Marks'] + df['Python Marks'] + df['Algorithm Marks']
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
import numpy as np 

df['A+ in DS'] = np.where(df['Data Structure Marks']>90, 'A+' , 'A')

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['Passed in DS'] = df['Data Structure Marks'] >70

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['First Name'] = df['FullName'].str.split(' ').str[0]

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df1 = pd.read_csv('student_data.csv')
df1
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.to_csv('new_data.csv')

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "Alice", "David", "Bob"],
    "City": ["New York", "London", "Paris", "New York", "Tokyo", "London"],
    "Score": [85, 90, 78, 85, 95, 90]
}

df = pd.DataFrame(data)
df
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     85
# 4    David     Tokyo     95
# 5      Bob    London     90

# %%
# unique works on only series 
df['Name'].unique()

df['Name'].unique()
# Out:
# <ArrowStringArray>
# ['Alice', 'Bob', 'Charlie', 'David']
# Length: 4, dtype: str

# %%
df1 = pd.read_csv('student_data.csv')
df1
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
len(df1['Data Structure Marks'].unique())

df1['Data Structure Marks'].nunique()
# Out:
# 12

# %%
df.nunique()
# Out:
# Name     4
# City     4
# Score    4
# dtype: int64

# %%
# Check null
df1.isnull()
# Out:
#     StudentID  FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0       False     False                 False            False         False
# 1       False     False                 False            False          True
# 2       False     False                 False            False         False
# 3       False     False                 False            False         False
# 4       False     False                  True             True         False
# 5       False     False                 False            False         False
# 6       False     False                 False            False          True
# 7       False     False                 False            False         False
# 8       False     False                 False            False         False
# 9       False     False                 False            False         False
# 10      False     False                  True             True         False
# ...

# %%
df1['Data Structure Marks'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# Name: Data Structure Marks, dtype: bool

# %%
df1['Data Structure Marks'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# Name: Data Structure Marks, dtype: bool

# %%
df1['Data Structure Marks'].hasnans
# Out:
# True

# %%
df1['StudentID'].hasnans
# Out:
# False

# %%
df1[['FullName','StudentID']]
# Out:
#             FullName StudentID
# 0        Alif Rahman    PH1001
# 1      Fatima Akhter    PH1002
# 2      Imran Hossain    PH1003
# 3   Jannatul Ferdous    PH1004
# 4        Kamal Uddin    PH1005
# 5        Laila Begum    PH1006
# 6     Mahmudul Hasan    PH1007
# 7        Nadia Islam    PH1008
# 8         Omar Faruq    PH1009
# 9       Priya Sharma    PH1010
# 10      Rahim Sheikh    PH1011
# 11   Sadia Chowdhury    PH1012
# 12      Tanvir Ahmed    PH1013
# 13        Urmi Akter    PH1014
# 14      Wahiduzzaman    PH1015
# 15      Ziaur Rahman    PH1016
# 16       Afsana Mimi    PH1017
# 17       Babul Ahmed    PH1018
# 18      Faria Rahman    PH1019
# 19        Nasir Khan    PH1020

# %%
# Handling Duplicates Values
import pandas as pd
data = {
    "Name": ["Alice", "Bob", "Charlie", "Alice", "David", "Bob"],
    "City": ["New York", "London", "Paris", "New York", "Tokyo", "London"],
    "Score": [85, 90, 78, 70, 95, 90]
}

df = pd.DataFrame(data)
df
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95
# 5      Bob    London     90

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
# delelting duplicates values 

df.drop_duplicates()
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95

# %%
# permanent 

df.drop_duplicates(inplace= True) 
df
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95

# %%
# name er basis e duplicate deletion 

df.drop_duplicates(subset=['Name'])
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 4    David     Tokyo     95

# %%
# city
df.drop_duplicates(subset=['City'])
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 4    David     Tokyo     95

# %%
df.drop_duplicates(subset=['Name'],keep='last')
# Out:
#       Name      City  Score
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95

# %%
df.drop_duplicates(subset=['Name'],keep='first')
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 4    David     Tokyo     95

# %%
# Handling Null values

df = pd.read_csv('student_data.csv')

df
df.dropna()
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
df.dropna(how='all',inplace = True) 
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.dropna(subset=['Python Marks'])
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# ...

# %%
df.dropna(subset=['Python Marks','Algorithm Marks'])
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
df.fillna(0)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   0.0              0.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   0.0              0.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['FullName'].fillna('unknown')
# Out:
# 0          Alif Rahman
# 1        Fatima Akhter
# 2        Imran Hossain
# 3     Jannatul Ferdous
# 4          Kamal Uddin
# 5          Laila Begum
# 6       Mahmudul Hasan
# 7          Nadia Islam
# 8           Omar Faruq
# 9         Priya Sharma
# 10        Rahim Sheikh
# 11     Sadia Chowdhury
# 12        Tanvir Ahmed
# 13          Urmi Akter
# 14        Wahiduzzaman
# 15        Ziaur Rahman
# 16         Afsana Mimi
# 17         Babul Ahmed
# 18        Faria Rahman
# 19          Nasir Khan
# Name: FullName, dtype: str

# %%
df['Python Marks'].fillna(df['Python Marks'].mean(),inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_96712\3283531364.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Python Marks'].fillna(df['Python Marks'].mean(),inplace=True)
# 0     88.000000
# 1     85.666667
# 2     85.000000
# 3     82.000000
# 4     95.000000
# 5     78.000000
# 6     85.666667
# 7     85.000000
# ...

# %%
# sum
df['Data Structure Marks'].sum()
# Out:
# np.float64(1344.0)

# %%
# max and min 
print(df['Data Structure Marks'].min())
df['Data Structure Marks'].max()
# Out:
# 72.0
# np.float64(94.0)

# %%
#mean -> average 

df['Data Structure Marks'].mean()
# Out:
# np.float64(84.0)

# %%
#median 
df['Data Structure Marks'].median()
# Out:
# np.float64(85.5)

# %%
# mode -> highest frequency er number 

df['Data Structure Marks'].mode()
# Out:
# 0    75.0
# 1    85.0
# 2    86.0
# 3    88.0
# Name: Data Structure Marks, dtype: float64

# %%
# standard deviation -> std 
df['Data Structure Marks'].std()
# Out:
# np.float64(6.501281924871945)

# %%
# correlation matrix 

df[['Data Structure Marks','Python Marks']].corr()
# Out:
#                       Data Structure Marks  Python Marks
# Data Structure Marks              1.000000      0.893455
# Python Marks                      0.893455      1.000000

# %%
# sum in different columns row wise
df[['Data Structure Marks','Python Marks']].sum(axis=1)
# Out:
# 0     173.0
# 1      92.0
# 2     173.0
# 3     160.0
# 4      95.0
# 5     153.0
# 6      80.0
# 7     166.0
# 8     148.0
# 9     177.0
# 10     91.0
# 11    172.0
# 12    154.0
# 13      0.0
# 14    170.0
# 15     94.0
# 16    183.0
# 17    173.0
# 18      0.0
# 19    175.0
# dtype: float64

# %%
df['Total Marks'] = df.iloc[::,2:5].sum(axis=1)

# %%
# apply function on df

#min max scaling 

mn = df['Total Marks'].min() 
mx = df['Total Marks'].max() 

df['Scaled Marks'] = df['Total Marks'].apply(lambda x : (x-mn)/(mx-mn))
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# custom built function 

def grading_system(marks):

    if marks >=260:
        return 'A+' 
    elif marks>=250:
        return 'A' 
    else:
        return 'A-'

df['Grade'] = df['Total Marks'].apply(grading_system)

# %%
def marking_system(df): 
    a = df['Data Structure Marks'] * 2 
    b = df['Python Marks'] * 3 
    c = df['Algorithm Marks'] * 4

    return a+b+c 

df['Exceptional Marks'] = df.apply(marking_system,axis=1)

# %%
import pandas as pd

# আপনার দেওয়া কমপ্লিটেড স্টুডেন্ট ডেটা ডিকশনারি আকারে সাজানো হয়েছে
completed_data = {
    "StudentID": [
        "PH0001", "PH0002", "PH0003", "PH0004", "PH0005", 
        "PH0006", "PH0007", "PH0008", "PH0009", "PH0010", 
        "PH0011", "PH0012", "PH0013", "PH0014", "PH0015", 
        "PH0016", "PH0017", "PH0018", "PH0019", "PH0020"
    ],
    "FullName": [
        "Alif Rahman", "Fatima Akhter", "Imran Hossain", "Jannatul Ferdous", "Kamal Uddin", 
        "Laila Begum", "Mahmudul Hasan", "Nadia Islam", "Omar Faruq", "Priya Sharma", 
        "Rahim Sheikh", "Sadia Chowdhury", "Tanvir Ahmed", "Urmi Akter", "Wahiduzzaman", 
        "Ziaur Rahman", "Afsana Mimi", "Babul Ahmed", "Faria Rahman", "Tariq Hasan"
    ],
    "CompletionStatus": ["Completed"] * 20,  # সবার স্ট্যাটাস যেহেতু Completed, তাই শর্টকাটে ২০ বার রিপিট করা হয়েছে
    "EnrollmentDate": [
        "2024-09-01", "2024-08-11", "2024-05-08", "2024-07-05", "2024-02-01", 
        "2024-09-07", "2024-06-07", "2024-03-22", "2024-02-12", "2024-06-19", 
        "2024-03-14", "2024-08-04", "2024-06-07", "2024-01-04", "2024-02-22", 
        "2024-03-23", "2024-01-18", "2024-06-23", "2024-04-19", "2024-07-21"
    ],
    "FinishedDate": [
        "2024-12-23", "2024-11-07", "2024-08-08", "2024-09-23", "2024-04-17", 
        "2024-12-31", "2024-07-20", "2024-05-01", "2024-06-08", "2024-08-19", 
        "2024-06-11", "2024-10-25", "2024-08-03", "2024-03-23", "2024-05-16", 
        "2024-06-21", "2024-03-16", "2024-09-20", "2024-08-17", "2024-10-11"
    ],
    "Instructor": [
        "Ms. Salma", "Mr. Karim", "Ms. Salma", "Mr. Karim", "Mr. David", 
        "Mr. David", "Mr. David", "Ms. Salma", "Mr. Karim", "Mr. David", 
        "Mr. Karim", "Mr. Karim", "Mr. David", "Mr. David", "Mr. David", 
        "Ms. Salma", "Mr. David", "Mr. David", "Mr. Karim", "Mr. Karim"
    ],
    "Location": [
        "Khulna", "Dhaka", "Dhaka", "Khulna", "Sylhet", 
        "Khulna", "Chattogram", "Khulna", "Dhaka", "Dhaka", 
        "Sylhet", "Sylhet", "Dhaka", "Sylhet", "Rajshahi", 
        "Rajshahi", "Khulna", "Dhaka", "Sylhet", "Khulna"
    ],
    "Total Marks": [
        300, 271, 269, 270, 254, 
        272, 249, 246, 291, 286, 
        283, 266, 248, 285, 291, 
        234, 236, 278, 277, 253
    ]
}

# ডেটাফ্রেম তৈরি করা হচ্ছে
df = pd.DataFrame(completed_data)

# 'student_completed_data.csv' নামে ফাইলটি সেভ করা হচ্ছে
df.to_csv("student_completed_data.csv", index=False)

print("আপনার student_completed_data.csv ফাইলটি সফলভাবে তৈরি হয়েছে!")
# Out:
# আপনার student_completed_data.csv ফাইলটি সফলভাবে তৈরি হয়েছে!

# %%
# datetime and time delta
df = pd.read_csv('student_completed_data.csv')
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
df['EnrollmentDate']
# Out:
# 0     2024-09-01
# 1     2024-08-11
# 2     2024-05-08
# 3     2024-07-05
# 4     2024-02-01
# 5     2024-09-07
# 6     2024-06-07
# 7     2024-03-22
# 8     2024-02-12
# 9     2024-06-19
# 10    2024-03-14
# 11    2024-08-04
# 12    2024-06-07
# 13    2024-01-04
# 14    2024-02-22
# 15    2024-03-23
# 16    2024-01-18
# 17    2024-06-23
# 18    2024-04-19
# 19    2024-07-21
# Name: EnrollmentDate, dtype: str

# %%
df['EnrollmentDate'] = pd.to_datetime(df['EnrollmentDate'])
df['EnrollmentDate']
# Out:
# 0    2024-09-01
# 1    2024-08-11
# 2    2024-05-08
# 3    2024-07-05
# 4    2024-02-01
# 5    2024-09-07
# 6    2024-06-07
# 7    2024-03-22
# 8    2024-02-12
# 9    2024-06-19
# 10   2024-03-14
# 11   2024-08-04
# 12   2024-06-07
# 13   2024-01-04
# 14   2024-02-22
# 15   2024-03-23
# 16   2024-01-18
# 17   2024-06-23
# 18   2024-04-19
# 19   2024-07-21
# Name: EnrollmentDate, dtype: datetime64[us]

# %%
df['Enrollment Year'] = df['EnrollmentDate'].dt.year 
df['Enrollment Date'] = df['EnrollmentDate'].dt.day
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
df['FinishedDate'] = pd.to_datetime(df['FinishedDate']) 
df['Total time taken to finish']= df['FinishedDate'] - df['EnrollmentDate']
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
# Groupby

import numpy as np

df.loc[df['FullName'] == 'Afsana Mimi', 'Total Marks'] = np.nan
df.loc[df['FullName'] == 'Sadia Chowdhury', 'Total Marks'] = np.nan
df.loc[df['FullName'] == 'Alif Rahman', 'Total Marks'] = np.nan
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
instructor_group = df.groupby('Instructor')

instructor_group

# %%
for instructor , df_ins in instructor_group : 
    print(instructor)
    display(df_ins)
# Out:
# Mr. David
#    StudentID        FullName CompletionStatus EnrollmentDate FinishedDate  \
# 4     PH0005     Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006     Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007  Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 9     PH0010    Priya Sharma        Completed     2024-06-19   2024-08-19
# 12    PH0013    Tanvir Ahmed        Completed     2024-06-07   2024-08-03
# 13    PH0014      Urmi Akter        Completed     2024-01-04   2024-03-23
# 14    PH0015    Wahiduzzaman        Completed     2024-02-22   2024-05-16
# 16    PH0017     Afsana Mimi        Completed     2024-01-18   2024-03-16
# 17    PH0018     Babul Ahmed        Completed     2024-06-23   2024-09-20
#
#    Instructor    Location  Total Marks  Enrollment Year  Enrollment Date  \
# 4   Mr. David      Sylhet        254.0             2024                1
# ...

# %%
# df.min()


instructor_group.min()
# Out:
#            StudentID      FullName CompletionStatus EnrollmentDate  \
# Instructor
# Mr. David     PH0005   Afsana Mimi        Completed     2024-01-04
# Mr. Karim     PH0002  Faria Rahman        Completed     2024-02-12
# Ms. Salma     PH0001   Alif Rahman        Completed     2024-03-22
#
#            FinishedDate    Location  Total Marks  Enrollment Year  \
# Instructor
# Mr. David    2024-03-16  Chattogram        248.0             2024
# Mr. Karim    2024-06-08       Dhaka        253.0             2024
# Ms. Salma    2024-05-01       Dhaka        234.0             2024
#
#             Enrollment Date Total time taken to finish
# Instructor
# Mr. David                 1                    43 days
# Mr. Karim                 4                    80 days
# Ms. Salma                 1                    40 days

# %%
instructor_group.describe()
# Out:
#            EnrollmentDate                                                   \
#                     count                        mean                  min
# Instructor
# Mr. David               9         2024-04-22 13:20:00  2024-01-04 00:00:00
# Mr. Karim               7  2024-05-30 03:25:42.857142  2024-02-12 00:00:00
# Ms. Salma               4         2024-05-13 18:00:00  2024-03-22 00:00:00
#
#                                                                            \
#                             25%                  50%                  75%
# Instructor
# Mr. David   2024-02-01 00:00:00  2024-06-07 00:00:00  2024-06-19 00:00:00
# Mr. Karim   2024-04-01 00:00:00  2024-07-05 00:00:00  2024-07-28 00:00:00
# Ms. Salma   2024-03-22 18:00:00  2024-04-15 00:00:00  2024-06-06 00:00:00
#
#                                      FinishedDate                              \
#                             max  std        count                        mean
# Instructor
# ...

# %%
mean_marks = instructor_group['Total Marks'].mean()

mean_marks
# Out:
# Instructor
# Mr. David    270.375000
# Mr. Karim    274.166667
# Ms. Salma    249.666667
# Name: Total Marks, dtype: float64

# %%
df['Total Marks']= df['Total Marks'].fillna(df['Instructor'].map(mean_marks)) 

df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...
