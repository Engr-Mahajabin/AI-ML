# %%
phn_num = 2837837
print(phn_num)
# Out:
# 2837837

# %%
name = 'Ritu'
print(name)
# Out:
# Ritu

# %%
age = 20
height = 5.6
name = 'ritu'
is_passed = True
print(type(age), type(height), type(name), type(is_passed))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
